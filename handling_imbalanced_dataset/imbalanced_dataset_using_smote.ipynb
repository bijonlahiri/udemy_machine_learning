# %% [markdown]
# # SMOTE (Synthetic Minority Oversampling Technique)
# It is a technique used in machine learning to address imbalanced datasets, where the minority class has significantly fewer instances than the majority class. SMOTE involves generating synthetic instances of the minority class by interpolating between existing instances.

# %%
from sklearn.datasets import make_classification
X, y = make_classification(
            n_samples=1000,
            n_features=2,
            n_redundant=0,
            n_clusters_per_class=1,
            weights=[0.90],
            random_state=12
        )

# %%
import pandas as pd
df1 = pd.DataFrame(X, columns=['f1', 'f2'])
df2 = pd.DataFrame(y, columns=['target'])
final_df = pd.concat([df1, df2], axis=1)
final_df
# Out:
#            f1        f2  target
# 0   -0.762898 -0.706808       0
# 1   -1.075436 -1.051162       0
# 2   -0.610115 -0.909802       0
# 3   -2.023284 -0.428945       1
# 4   -0.812921 -1.316206       0
# ..        ...       ...     ...
# 995 -0.712495 -0.880452       0
# 996 -2.625830 -2.827891       0
# 997 -1.326439 -1.815178       0
# 998 -0.833486 -0.514647       0
# 999 -0.302876 -0.575975       0
#
# [1000 rows x 3 columns]

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'], final_df['f2'], c=final_df['target'])

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/venv/lib/python3.12/site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/venv/lib/python3.12/site-packages (from imblearn) (0.14.1)
# Requirement already satisfied: numpy<3,>=1.25.2 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/venv/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (2.4.1)
# Requirement already satisfied: scipy<2,>=1.11.4 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/venv/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (1.17.0)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/venv/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (1.8.0)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/venv/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/venv/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/venv/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (3.6.0)

# %%
from imblearn.over_sampling import SMOTE

# %%
# Transform the dataset 
oversample = SMOTE()
X, y = oversample.fit_resample(final_df[['f1', 'f2']], final_df['target'])

# %%
X.shape
# Out:
# (1800, 2)

# %%
y.value_counts()
# Out:
# target
# 0    900
# 1    900
# Name: count, dtype: int64

# %%
oversampled_df = pd.concat(
    [
        pd.DataFrame(X, columns=['f1', 'f2']),
        pd.DataFrame(y, columns=['target'])
    ],
    axis=1
)
oversampled_df
# Out:
#             f1        f2  target
# 0    -0.762898 -0.706808       0
# 1    -1.075436 -1.051162       0
# 2    -0.610115 -0.909802       0
# 3    -2.023284 -0.428945       1
# 4    -0.812921 -1.316206       0
# ...        ...       ...     ...
# 1795 -0.226265  2.043852       1
# 1796 -0.659445  1.273569       1
# 1797 -0.775817  1.504590       1
# 1798 -0.024288  2.033303       1
# 1799 -1.417590  0.906436       1
#
# [1800 rows x 3 columns]

# %%
plt.scatter(oversampled_df['f1'], oversampled_df['f2'], c=oversampled_df['target'])
