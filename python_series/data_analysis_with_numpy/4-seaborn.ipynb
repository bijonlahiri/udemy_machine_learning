# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/python_series/venv/lib/python3.12/site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: pandas>=1.2 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/python_series/venv/lib/python3.12/site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/python_series/venv/lib/python3.12/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/python_series/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/python_series/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/python_series/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/python_series/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/python_series/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/python_series/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/python_series/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/python_series/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/python_series/venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/python_series/venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/bijonlahiri/Desktop/udemy_machine_learning_course/python_series/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns

# %%
# Basic plotting with seaborn
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import matplotlib.pyplot as plt
# Create a scatter plot
sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title('Total Bill vs Tip')
plt.show()

# %%
# line plot
sns.lineplot(x='size',y='total_bill',data=tips)
plt.title('Size vs Total Bill')
plt.show()

# %%
# Categorical plots
# Bar plot
sns.barplot(x='day',y='total_bill', data=tips)
plt.title('Total Bill per Day')
plt.show()

# %%
# Box plot
sns.boxplot(x='day',y='total_bill',data=tips)
plt.title('Box plot of Total Bill per Day')
plt.show()

# %%
#violin plot for data distribution
sns.violinplot(x='day',y='total_bill',data=tips)
plt.title('Violin plot of Total Bill per Day')
plt.show()

# %%
# Heat map
corr=tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.title('Heatmap of Correlation Matrix')
plt.show()
